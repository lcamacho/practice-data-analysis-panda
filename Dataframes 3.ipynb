# %%
import pandas as pd

# %%
bond = pd.read_csv("jamesbond.csv")
bond.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
bond.set_index('Film', inplace=True)

# %%
bond.head(3)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
bond.reset_index(inplace=True)

# %%
bond.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
bond.set_index('Film', inplace=True)

# %%
bond.set_index('Year') #elimina el index anterior si existia, primero es mejor resetear el index
# Out:
#                Actor            Director  Box Office  Budget  \
# Year
# 1962    Sean Connery       Terence Young       448.8     7.0
# 1963    Sean Connery       Terence Young       543.8    12.6
# 1964    Sean Connery        Guy Hamilton       820.4    18.6
# 1965    Sean Connery       Terence Young       848.1    41.9
# 1967     David Niven          Ken Hughes       315.0    85.0
# 1967    Sean Connery       Lewis Gilbert       514.2    59.9
# 1969  George Lazenby       Peter R. Hunt       291.5    37.3
# 1971    Sean Connery        Guy Hamilton       442.5    34.7
# 1973     Roger Moore        Guy Hamilton       460.3    30.8
# 1974     Roger Moore        Guy Hamilton       334.0    27.7
# 1977     Roger Moore       Lewis Gilbert       533.0    45.1
# 1979     Roger Moore       Lewis Gilbert       535.0    91.5
# 1981     Roger Moore           John Glen       449.4    60.2
# 1983    Sean Connery      Irvin Kershner       380.0    86.0
# ...

# %%
bond.reset_index(inplace=True)

# %%
bond.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
bond = pd.read_csv("jamesbond.csv", index_col='Film')
bond.sort_index(inplace=True) #para mejorar el performance
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.loc['Goldfinger'] #loc ubica la fila por la etiqueta del index
# Out:
# Year                         1964
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: Goldfinger, dtype: object

# %%
bond.loc['Diamonds Are Forever':"From Russia with Love"] #el limite superior es incluido
bond.loc['Diamonds Are Forever':"From Russia with Love":2]
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery   Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6

# %%
bond.loc["GoldenEye":]
# Out:
#                                  Year           Actor            Director  \
# Film
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# ...

# %%
bond.loc[:"On Her Majesty's Secret Service"]
# Out:
#                                  Year           Actor         Director  \
# Film
# A View to a Kill                 1985     Roger Moore        John Glen
# Casino Royale                    2006    Daniel Craig  Martin Campbell
# Casino Royale                    1967     David Niven       Ken Hughes
# Diamonds Are Forever             1971    Sean Connery     Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan     Lee Tamahori
# Dr. No                           1962    Sean Connery    Terence Young
# For Your Eyes Only               1981     Roger Moore        John Glen
# From Russia with Love            1963    Sean Connery    Terence Young
# GoldenEye                        1995  Pierce Brosnan  Martin Campbell
# Goldfinger                       1964    Sean Connery     Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton        John Glen
# Live and Let Die                 1973     Roger Moore     Guy Hamilton
# ...

# %%
bond.loc[['Die Another Day', 'Octopussy']] #aparece en el orden declarado, falla si el key no existe
# Out:
#                  Year           Actor      Director  Box Office  Budget  \
# Film
# Die Another Day  2002  Pierce Brosnan  Lee Tamahori       465.4   154.2
# Octopussy        1983     Roger Moore     John Glen       373.8    53.9
#
#                  Bond Actor Salary
# Film
# Die Another Day               17.9
# Octopussy                      7.8

# %%
'Secret Bond' in bond.index
# Out:
# False

# %%
bond.iloc[0] #index location busca por numero de fila
# Out:
# Year                        1985
# Actor                Roger Moore
# Director               John Glen
# Box Office                 275.2
# Budget                      54.5
# Bond Actor Salary            9.1
# Name: A View to a Kill, dtype: object

# %%
bond.iloc[4:8] #muestra desde el 4 hasta el 7, el 8 no se incluye
# Out:
#                        Year           Actor       Director  Box Office  \
# Film
# Die Another Day        2002  Pierce Brosnan   Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery  Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore      John Glen       449.4
# From Russia with Love  1963    Sean Connery  Terence Young       543.8
#
#                        Budget  Bond Actor Salary
# Film
# Die Another Day         154.2               17.9
# Dr. No                    7.0                0.6
# For Your Eyes Only       60.2                NaN
# From Russia with Love    12.6                1.6

# %%
bond.iloc[[15,8,20]] #se muestra en el orden buscado, falla si se busca una fila q no existe
# Out:
#                                  Year           Actor         Director  \
# Film
# On Her Majesty's Secret Service  1969  George Lazenby    Peter R. Hunt
# GoldenEye                        1995  Pierce Brosnan  Martin Campbell
# The Man with the Golden Gun      1974     Roger Moore     Guy Hamilton
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# On Her Majesty's Secret Service       291.5    37.3                0.6
# GoldenEye                             518.5    76.9                5.1
# The Man with the Golden Gun           334.0    27.7                NaN

# %%
bond.iloc[20:]
bond.iloc[:10]
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# A View to a Kill       1985     Roger Moore        John Glen       275.2
# Casino Royale          2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale          1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever   1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day        2002  Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery    Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore        John Glen       449.4
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# Goldfinger             1964    Sean Connery     Guy Hamilton       820.4
#
#                        Budget  Bond Actor Salary
# Film
# A View to a Kill         54.5                9.1
# Casino Royale           145.3                3.3
# ...

# %%
bond.loc['Moonraker', 'Actor']
# Out:
# 'Roger Moore'

# %%
bond.loc['Moonraker', ['Director', 'Box Office']]
# Out:
# Director      Lewis Gilbert
# Box Office              535
# Name: Moonraker, dtype: object

# %%
bond.loc[['Moonraker', 'A View to a Kill'], ['Director', 'Box Office']]
# Out:
#                        Director  Box Office
# Film
# Moonraker         Lewis Gilbert       535.0
# A View to a Kill      John Glen       275.2

# %%
bond.loc['Moonraker':'Thunderball', 'Director':'Budget']
# Out:
#                                        Director  Box Office  Budget
# Film
# Moonraker                         Lewis Gilbert       535.0    91.5
# Never Say Never Again            Irvin Kershner       380.0    86.0
# Octopussy                             John Glen       373.8    53.9
# On Her Majesty's Secret Service   Peter R. Hunt       291.5    37.3
# Quantum of Solace                  Marc Forster       514.2   181.4
# Skyfall                              Sam Mendes       943.5   170.2
# Spectre                              Sam Mendes       726.7   206.3
# The Living Daylights                  John Glen       313.5    68.8
# The Man with the Golden Gun        Guy Hamilton       334.0    27.7
# The Spy Who Loved Me              Lewis Gilbert       533.0    45.1
# The World Is Not Enough           Michael Apted       439.5   158.3
# Thunderball                       Terence Young       848.1    41.9

# %%
bond.loc['Moonraker':, 'Director':]
# Out:
#                                            Director  Box Office  Budget  \
# Film
# Moonraker                             Lewis Gilbert       535.0    91.5
# Never Say Never Again                Irvin Kershner       380.0    86.0
# Octopussy                                 John Glen       373.8    53.9
# On Her Majesty's Secret Service       Peter R. Hunt       291.5    37.3
# Quantum of Solace                      Marc Forster       514.2   181.4
# Skyfall                                  Sam Mendes       943.5   170.2
# Spectre                                  Sam Mendes       726.7   206.3
# The Living Daylights                      John Glen       313.5    68.8
# The Man with the Golden Gun            Guy Hamilton       334.0    27.7
# The Spy Who Loved Me                  Lewis Gilbert       533.0    45.1
# The World Is Not Enough               Michael Apted       439.5   158.3
# Thunderball                           Terence Young       848.1    41.9
# ...

# %%
bond.loc[:'Moonraker', :'Budget']
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# A View to a Kill       1985     Roger Moore        John Glen       275.2
# Casino Royale          2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale          1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever   1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day        2002  Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery    Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore        John Glen       449.4
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# Goldfinger             1964    Sean Connery     Guy Hamilton       820.4
# Licence to Kill        1989  Timothy Dalton        John Glen       250.9
# Live and Let Die       1973     Roger Moore     Guy Hamilton       460.3
# ...

# %%
bond.iloc[14, 2]
# Out:
# 'John Glen'

# %%
bond.iloc[14, 2:5] # la columna 5 no es incluida
# aqui funciona las diferentes combinaciones de listas [:'key'], ['key':] etc
# Out:
# Director      John Glen
# Box Office        373.8
# Budget             53.9
# Name: Octopussy, dtype: object

# %%
bond.iloc[[14, 17], [2, 4]]
# Out:
#              Director  Budget
# Film
# Octopussy   John Glen    53.9
# Skyfall    Sam Mendes   170.2

# %%
bond_copy = bond.copy()

# %%
bond_copy.loc['Dr. No', 'Actor'] = 'Sir Sean Connery' #modifica un valor

# %%
bond_copy.loc['Dr. No', 'Actor']
# Out:
# 'Sir Sean Connery'

# %%
bond_copy.loc['Dr. No', ['Box Office', 'Budget', 'Bond Actor Salary']] = [448000000, 7000000, 600000]

# %%
bond_copy.loc['Dr. No', ['Box Office', 'Budget', 'Bond Actor Salary']]
# Out:
# Box Office           4.48e+08
# Budget                  7e+06
# Bond Actor Salary      600000
# Name: Dr. No, dtype: object

# %%
bond_copy = bond.copy()

# %%
actor = bond_copy['Actor'] == 'Sean Connery'

# %%
bond_copy.loc[actor, 'Actor']
# Out:
# Film
# Diamonds Are Forever     Sir Sean Connery
# Dr. No                   Sir Sean Connery
# From Russia with Love    Sir Sean Connery
# Goldfinger               Sir Sean Connery
# Never Say Never Again    Sir Sean Connery
# Thunderball              Sir Sean Connery
# You Only Live Twice      Sir Sean Connery
# Name: Actor, dtype: object

# %%
bond_copy.loc[actor, 'Actor'] = 'Sir Sean Connery'

# %%
bond_copy
# Out:
#                                  Year             Actor            Director  \
# Film
# A View to a Kill                 1985       Roger Moore           John Glen
# Casino Royale                    2006      Daniel Craig     Martin Campbell
# Casino Royale                    1967       David Niven          Ken Hughes
# Diamonds Are Forever             1971  Sir Sean Connery        Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# Dr. No                           1962  Sir Sean Connery       Terence Young
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963  Sir Sean Connery       Terence Young
# GoldenEye                        1995    Pierce Brosnan     Martin Campbell
# Goldfinger                       1964  Sir Sean Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# ...

# %%
bond_copy = bond.copy()

# %%
bond_copy.rename({'GoldenEye': 'Golden Eye'})
bond_copy.rename({'GoldenEye': 'Golden Eye'}, axis = 0)
bond_copy.rename({'GoldenEye': 'Golden Eye'}, axis = 'rows')
bond_copy.rename({'GoldenEye': 'Golden Eye'}, axis = 'index')
bond_copy.rename(index={'GoldenEye': 'Golden Eye'}, inplace=True)

# %%
bond_copy
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# Golden Eye                       1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
bond_copy.rename({'Year': 'Release Date'}, axis=1)
bond_copy.rename({'Year': 'Release Date'}, axis="columns")
bond_copy.rename(columns={'Year': 'Release Date'}, inplace=True)

# %%
bond_copy
# Out:
#                                  Release Date           Actor  \
# Film
# A View to a Kill                         1985     Roger Moore
# Casino Royale                            2006    Daniel Craig
# Casino Royale                            1967     David Niven
# Diamonds Are Forever                     1971    Sean Connery
# Die Another Day                          2002  Pierce Brosnan
# Dr. No                                   1962    Sean Connery
# For Your Eyes Only                       1981     Roger Moore
# From Russia with Love                    1963    Sean Connery
# Golden Eye                               1995  Pierce Brosnan
# Goldfinger                               1964    Sean Connery
# Licence to Kill                          1989  Timothy Dalton
# Live and Let Die                         1973     Roger Moore
# Moonraker                                1979     Roger Moore
# Never Say Never Again                    1983    Sean Connery
# ...

# %%
bond_copy.columns #se puede escribir en esta propiedad
# Out:
# Index(['Release Date', 'Actor', 'Director', 'Box Office', 'Budget',
#        'Bond Actor Salary'],
#       dtype='object')

# %%
bond_copy.columns = ['Year of release', 'Actor', 'Director', 'Box Office', 'Budget', 'Bond Actor Salary']

# %%
bond_copy.head(1)
# Out:
#                   Year of release        Actor   Director  Box Office  Budget  \
# Film
# A View to a Kill             1985  Roger Moore  John Glen       275.2    54.5
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1

# %%
bond_copy = bond.copy()

# %%
bond_copy.drop('GoldenEye') # remueve una fila
bond_copy.drop(['GoldenEye', 'Octopussy']) #falta el inplace=True
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
bond_copy.drop(['Actor', 'Bond Actor Salary'], axis = 'columns') # remueve columnas, falta el inplace=True
bond_copy.drop(['Actor', 'Bond Actor Salary'], axis = 1)
# Out:
#                                  Year            Director  Box Office  Budget
# Film
# A View to a Kill                 1985           John Glen       275.2    54.5
# Casino Royale                    2006     Martin Campbell       581.5   145.3
# Casino Royale                    1967          Ken Hughes       315.0    85.0
# Diamonds Are Forever             1971        Guy Hamilton       442.5    34.7
# Die Another Day                  2002        Lee Tamahori       465.4   154.2
# Dr. No                           1962       Terence Young       448.8     7.0
# For Your Eyes Only               1981           John Glen       449.4    60.2
# From Russia with Love            1963       Terence Young       543.8    12.6
# GoldenEye                        1995     Martin Campbell       518.5    76.9
# Goldfinger                       1964        Guy Hamilton       820.4    18.6
# Licence to Kill                  1989           John Glen       250.9    56.7
# ...

# %%
actor = bond_copy.pop('Actor') #saca por completo la serie del dataframe y la devuelve

# %%
bond_copy.head(1)
# Out:
#                   Year   Director  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill  1985  John Glen       275.2    54.5                9.1

# %%
actor
# Out:
# Film
# A View to a Kill                      Roger Moore
# Casino Royale                        Daniel Craig
# Casino Royale                         David Niven
# Diamonds Are Forever                 Sean Connery
# Die Another Day                    Pierce Brosnan
# Dr. No                               Sean Connery
# For Your Eyes Only                    Roger Moore
# From Russia with Love                Sean Connery
# GoldenEye                          Pierce Brosnan
# Goldfinger                           Sean Connery
# Licence to Kill                    Timothy Dalton
# Live and Let Die                      Roger Moore
# Moonraker                             Roger Moore
# Never Say Never Again                Sean Connery
# Octopussy                             Roger Moore
# On Her Majesty's Secret Service    George Lazenby
# Quantum of Solace                    Daniel Craig
# Skyfall                              Daniel Craig
# Spectre                              Daniel Craig
# ...

# %%
del bond_copy['Budget'] #elimina la serie por completo

# %%
bond_copy
# Out:
#                                  Year            Director  Box Office  \
# Film
# A View to a Kill                 1985           John Glen       275.2
# Casino Royale                    2006     Martin Campbell       581.5
# Casino Royale                    1967          Ken Hughes       315.0
# Diamonds Are Forever             1971        Guy Hamilton       442.5
# Die Another Day                  2002        Lee Tamahori       465.4
# Dr. No                           1962       Terence Young       448.8
# For Your Eyes Only               1981           John Glen       449.4
# From Russia with Love            1963       Terence Young       543.8
# GoldenEye                        1995     Martin Campbell       518.5
# Goldfinger                       1964        Guy Hamilton       820.4
# Licence to Kill                  1989           John Glen       250.9
# Live and Let Die                 1973        Guy Hamilton       460.3
# ...

# %%
bond_copy = bond.copy()

# %%
bond.sample()
# Out:
#                     Year        Actor   Director  Box Office  Budget  \
# Film
# For Your Eyes Only  1981  Roger Moore  John Glen       449.4    60.2
#
#                     Bond Actor Salary
# Film
# For Your Eyes Only                NaN

# %%
bond.sample(5)
# Out:
#                              Year         Actor       Director  Box Office  \
# Film
# You Only Live Twice          1967  Sean Connery  Lewis Gilbert       514.2
# Dr. No                       1962  Sean Connery  Terence Young       448.8
# Spectre                      2015  Daniel Craig     Sam Mendes       726.7
# The Man with the Golden Gun  1974   Roger Moore   Guy Hamilton       334.0
# For Your Eyes Only           1981   Roger Moore      John Glen       449.4
#
#                              Budget  Bond Actor Salary
# Film
# You Only Live Twice            59.9                4.4
# Dr. No                          7.0                0.6
# Spectre                       206.3                NaN
# The Man with the Golden Gun    27.7                NaN
# For Your Eyes Only             60.2                NaN

# %%
bond.sample(frac = .25) # para obtener un % del dataframe en este caso 25%
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# Casino Royale          1967   David Niven      Ken Hughes       315.0    85.0
# Octopussy              1983   Roger Moore       John Glen       373.8    53.9
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Live and Let Die       1973   Roger Moore    Guy Hamilton       460.3    30.8
# Quantum of Solace      2008  Daniel Craig    Marc Forster       514.2   181.4
#
#                        Bond Actor Salary
# Film
# Thunderball                          4.7
# Casino Royale                        NaN
# Octopussy                            7.8
# Never Say Never Again                NaN
# Live and Let Die                     NaN
# Quantum of Solace                    8.1

# %%
bond.sample(n=3, axis='columns') # selecciona 3 columnas aleatoriamente
# Out:
#                                  Bond Actor Salary  Budget            Director
# Film
# A View to a Kill                               9.1    54.5           John Glen
# Casino Royale                                  3.3   145.3     Martin Campbell
# Casino Royale                                  NaN    85.0          Ken Hughes
# Diamonds Are Forever                           5.8    34.7        Guy Hamilton
# Die Another Day                               17.9   154.2        Lee Tamahori
# Dr. No                                         0.6     7.0       Terence Young
# For Your Eyes Only                             NaN    60.2           John Glen
# From Russia with Love                          1.6    12.6       Terence Young
# GoldenEye                                      5.1    76.9     Martin Campbell
# Goldfinger                                     3.2    18.6        Guy Hamilton
# Licence to Kill                                7.9    56.7           John Glen
# ...

# %%
bond.sort_values('Box Office', ascending=False).head(3)
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond.nlargest(3, 'Box Office')
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond.nsmallest(3, 'Box Office')
# Out:
#                                  Year           Actor       Director  \
# Film
# Licence to Kill                  1989  Timothy Dalton      John Glen
# A View to a Kill                 1985     Roger Moore      John Glen
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Licence to Kill                       250.9    56.7                7.9
# A View to a Kill                      275.2    54.5                9.1
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %%
bond['Box Office'].nlargest(3)
# Out:
# Film
# Skyfall        943.5
# Thunderball    848.1
# Goldfinger     820.4
# Name: Box Office, dtype: float64

# %%
bond['Year'].nsmallest(2)
# Out:
# Film
# Dr. No                   1962
# From Russia with Love    1963
# Name: Year, dtype: int64

# %%
mask = bond['Actor'] == 'Sean Connery'

# %%
bond.where(mask)
# Out:
#                                    Year         Actor        Director  \
# Film
# A View to a Kill                    NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Die Another Day                     NaN           NaN             NaN
# Dr. No                           1962.0  Sean Connery   Terence Young
# For Your Eyes Only                  NaN           NaN             NaN
# From Russia with Love            1963.0  Sean Connery   Terence Young
# GoldenEye                           NaN           NaN             NaN
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Licence to Kill                     NaN           NaN             NaN
# Live and Let Die                    NaN           NaN             NaN
# ...

# %%
mask2 = bond['Box Office'] > 800
bond.where(mask & mask2)
# Out:
#                                    Year         Actor       Director  \
# Film
# A View to a Kill                    NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Die Another Day                     NaN           NaN            NaN
# Dr. No                              NaN           NaN            NaN
# For Your Eyes Only                  NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# GoldenEye                           NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Licence to Kill                     NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# ...

# %%
bond_copy.columns = [column_name.replace(' ', '_') for column_name in bond_copy.columns]
# Antes de usar query todos los nombre de las columnas no deben tener espacio

# %%
bond_copy.head(1)
# Out:
#                   Year        Actor   Director  Box_Office  Budget  \
# Film
# A View to a Kill  1985  Roger Moore  John Glen       275.2    54.5
#
#                   Bond_Actor_Salary
# Film
# A View to a Kill                9.1

# %%
bond_copy.query('Actor == "Sean Connery"')
# Out:
#                        Year         Actor        Director  Box_Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond_Actor_Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
bond_copy.query('Actor != "Roger Moore"')
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# ...

# %%
bond_copy.query('Box_Office > 600')
# Out:
#              Year         Actor       Director  Box_Office  Budget  \
# Film
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Spectre      2015  Daniel Craig     Sam Mendes       726.7   206.3
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
#
#              Bond_Actor_Salary
# Film
# Goldfinger                 3.2
# Skyfall                   14.5
# Spectre                    NaN
# Thunderball                4.7

# %%
bond_copy.query('Actor == "Roger Moore" and Director == "John Glen"')
bond_copy.query('Actor == "Roger Moore" or Director == "John Glen"')
# Out:
#                              Year           Actor       Director  Box_Office  \
# Film
# A View to a Kill             1985     Roger Moore      John Glen       275.2
# For Your Eyes Only           1981     Roger Moore      John Glen       449.4
# Licence to Kill              1989  Timothy Dalton      John Glen       250.9
# Live and Let Die             1973     Roger Moore   Guy Hamilton       460.3
# Moonraker                    1979     Roger Moore  Lewis Gilbert       535.0
# Octopussy                    1983     Roger Moore      John Glen       373.8
# The Living Daylights         1987  Timothy Dalton      John Glen       313.5
# The Man with the Golden Gun  1974     Roger Moore   Guy Hamilton       334.0
# The Spy Who Loved Me         1977     Roger Moore  Lewis Gilbert       533.0
#
#                              Budget  Bond_Actor_Salary
# Film
# A View to a Kill               54.5                9.1
# For Your Eyes Only             60.2                NaN
# ...

# %%
bond_copy.query('Actor in ["Timothy Dalton", "George Lazenby"]')
bond_copy.query('Actor not in ["Sean Connery", "Roger Moore"]')
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Licence to Kill                  1989  Timothy Dalton           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
#
# ...

# %%
bond_copy = bond.copy()

# %%
def convert_and_add_millions(number):
    return str(number) + " Millions!"

# %%
bond_copy['Box Office'].apply(convert_and_add_millions)
# Out:
# Film
# A View to a Kill                   275.2 Millions!
# Casino Royale                      581.5 Millions!
# Casino Royale                      315.0 Millions!
# Diamonds Are Forever               442.5 Millions!
# Die Another Day                    465.4 Millions!
# Dr. No                             448.8 Millions!
# For Your Eyes Only                 449.4 Millions!
# From Russia with Love              543.8 Millions!
# GoldenEye                          518.5 Millions!
# Goldfinger                         820.4 Millions!
# Licence to Kill                    250.9 Millions!
# Live and Let Die                   460.3 Millions!
# Moonraker                          535.0 Millions!
# Never Say Never Again              380.0 Millions!
# Octopussy                          373.8 Millions!
# On Her Majesty's Secret Service    291.5 Millions!
# Quantum of Solace                  514.2 Millions!
# Skyfall                            943.5 Millions!
# ...

# %%
columns = ['Box Office', 'Budget', 'Bond Actor Salary']

for col in columns:
    bond_copy[col] = bond_copy[col].apply(convert_and_add_millions)

# %%
bond_copy.head(3)
# Out:
#                   Year         Actor         Director       Box Office  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen  275.2 Millions!
# Casino Royale     2006  Daniel Craig  Martin Campbell  581.5 Millions!
# Casino Royale     1967   David Niven       Ken Hughes  315.0 Millions!
#
#                            Budget Bond Actor Salary
# Film
# A View to a Kill   54.5 Millions!     9.1 Millions!
# Casino Royale     145.3 Millions!     3.3 Millions!
# Casino Royale      85.0 Millions!     nan Millions!

# %%
bond_copy = bond.copy()

# %%
def good_movie(row):
    
    actor = row[1]
    budget = row[4]
    
    if actor == "Pierce Brosnan":
        return "The Best"
    elif actor == "Roger Moore" and budget > 40:
        return "Enjoyable"
    else:
        return "I have no clue"
    
bond.apply(good_movie, axis='columns')  # el axis cambia para que se leean todas las columnas de cada fila
# Out:
# Film
# A View to a Kill                        Enjoyable
# Casino Royale                      I have no clue
# Casino Royale                      I have no clue
# Diamonds Are Forever               I have no clue
# Die Another Day                          The Best
# Dr. No                             I have no clue
# For Your Eyes Only                      Enjoyable
# From Russia with Love              I have no clue
# GoldenEye                                The Best
# Goldfinger                         I have no clue
# Licence to Kill                    I have no clue
# Live and Let Die                   I have no clue
# Moonraker                               Enjoyable
# Never Say Never Again              I have no clue
# Octopussy                               Enjoyable
# On Her Majesty's Secret Service    I have no clue
# Quantum of Solace                  I have no clue
# Skyfall                            I have no clue
# Spectre                            I have no clue
# ...

# %%
directors = bond_copy['Director']

# %%
directors.head(3)
# Out:
# Film
# A View to a Kill          John Glen
# Casino Royale       Martin Campbell
# Casino Royale            Ken Hughes
# Name: Director, dtype: object

# %%
directors['A View to a Kill'] = 'Mister John Glen'
# Out:
# <ipython-input-145-0c2d3e1651f0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directors['A View to a Kill'] = 'Mister John Glen'

# %%
directors
# Out:
# Film
# A View to a Kill                     Mister John Glen
# Casino Royale                         Martin Campbell
# Casino Royale                              Ken Hughes
# Diamonds Are Forever                     Guy Hamilton
# Die Another Day                          Lee Tamahori
# Dr. No                                  Terence Young
# For Your Eyes Only                          John Glen
# From Russia with Love                   Terence Young
# GoldenEye                             Martin Campbell
# Goldfinger                               Guy Hamilton
# Licence to Kill                             John Glen
# Live and Let Die                         Guy Hamilton
# Moonraker                               Lewis Gilbert
# Never Say Never Again                  Irvin Kershner
# Octopussy                                   John Glen
# On Her Majesty's Secret Service         Peter R. Hunt
# Quantum of Solace                        Marc Forster
# ...

# %%
bond_copy.head(3)
# Out:
#                   Year         Actor          Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore  Mister John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig   Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven        Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond_copy = bond.copy()
directors = bond_copy['Director'].copy()
directors.head(3)
# Out:
# Film
# A View to a Kill          John Glen
# Casino Royale       Martin Campbell
# Casino Royale            Ken Hughes
# Name: Director, dtype: object

# %%
directors['A View to a Kill'] = 'Mister John Glen'
directors.head(3)
# Out:
# Film
# A View to a Kill    Mister John Glen
# Casino Royale        Martin Campbell
# Casino Royale             Ken Hughes
# Name: Director, dtype: object

# %%
bond_copy.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN
